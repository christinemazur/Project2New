# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
csv_file = "Donald-Tweets.csv"
donald_csv_df = pd.read_csv(csv_file)
donald_csv_df
# Out:
#           Date      Time                                         Tweet_Text  \
# 0     16-11-11  15:26:37  Today we express our deepest gratitude to all ...
# 1     16-11-11  13:33:35  Busy day planned in New York. Will soon be mak...
# 2     16-11-11  11:14:20  Love the fact that the small groups of protest...
# 3     16-11-11   2:19:44  Just had a very open and successful presidenti...
# 4     16-11-11   2:10:46  A fantastic day in D.C. Met with President Oba...
# ...        ...       ...                                                ...
# 7370  15-07-16  13:10:00  I loved firing goofball atheist Penn @pennjill...
# 7371  15-07-16  10:18:31  I hear @pennjillette show on Broadway is terri...
# 7372  15-07-16  10:10:17  Irrelevant clown @KarlRove sweats and shakes n...
# 7373  15-07-16   9:44:07  "@HoustonWelder: Donald Trump is one of the se...
# 7374  15-07-16   0:21:25  RT @marklevinshow: Trump: Rove is a clown and ...
#
#       Type Media_Type   Hashtags      Tweet_Id  \
# 0     text      photo  ThankAVet  7.970000e+17
# 1     text        NaN        NaN  7.970000e+17
# 2     text        NaN        NaN  7.970000e+17
# 3     text        NaN        NaN  7.970000e+17
# 4     text        NaN        NaN  7.970000e+17
# ...    ...        ...        ...           ...
# 7370  text        NaN        NaN  6.220000e+17
# 7371  text        NaN        NaN  6.220000e+17
# 7372  text        NaN        NaN  6.220000e+17
# 7373  text        NaN        NaN  6.220000e+17
# 7374  link        NaN        NaN  6.210000e+17
#
#                                               Tweet_Url  \
# 0     https://twitter.com/realDonaldTrump/status/797...
# 1     https://twitter.com/realDonaldTrump/status/797...
# 2     https://twitter.com/realDonaldTrump/status/797...
# 3     https://twitter.com/realDonaldTrump/status/796...
# 4     https://twitter.com/realDonaldTrump/status/796...
# ...                                                 ...
# 7370  https://twitter.com/realDonaldTrump/status/621...
# 7371  https://twitter.com/realDonaldTrump/status/621...
# 7372  https://twitter.com/realDonaldTrump/status/621...
# 7373  https://twitter.com/realDonaldTrump/status/621...
# 7374  https://twitter.com/realDonaldTrump/status/621...
#
#       twt_favourites_IS_THIS_LIKE_QUESTION_MARK  Retweets  Unnamed: 10  \
# 0                                        127213     41112          NaN
# 1                                        141527     28654          NaN
# 2                                        183729     50039          NaN
# 3                                        214001     67010          NaN
# 4                                        178499     36688          NaN
# ...                                         ...       ...          ...
# 7370                                        953       431          NaN
# 7371                                       1175      1086          NaN
# 7372                                       1494       930          NaN
# 7373                                       1800      1738          NaN
# 7374                                        962       689          NaN
#
#       Unnamed: 11
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 7370          NaN
# 7371          NaN
# 7372          NaN
# 7373          NaN
# 7374          NaN
#
# [7375 rows x 12 columns]

# %%
for col in donald_csv_df.columns: 
    print(col)
# Out:
# Date
# Time
# Tweet_Text
# Type
# Media_Type
# Hashtags
# Tweet_Id
# Tweet_Url
# twt_favourites_IS_THIS_LIKE_QUESTION_MARK
# Retweets
# Unnamed: 10
# Unnamed: 11

# %%
clean_csv_df = donald_csv_df[["Date", "Tweet_Text", "Hashtags", "twt_favourites_IS_THIS_LIKE_QUESTION_MARK", "Retweets"]].copy()
clean_csv_df.rename(columns={'Date':'date', 'Tweet_Text': 'tweet_text', 'Hashtags': 'hashtags', 'twt_favourites_IS_THIS_LIKE_QUESTION_MARK': 'twt_favourites_is_this_like_question_mark', 'Retweets':'retweets'}, inplace=True)
clean_csv_df
# Out:
#           date                                         tweet_text   hashtags  \
# 0     16-11-11  Today we express our deepest gratitude to all ...  ThankAVet
# 1     16-11-11  Busy day planned in New York. Will soon be mak...        NaN
# 2     16-11-11  Love the fact that the small groups of protest...        NaN
# 3     16-11-11  Just had a very open and successful presidenti...        NaN
# 4     16-11-11  A fantastic day in D.C. Met with President Oba...        NaN
# ...        ...                                                ...        ...
# 7370  15-07-16  I loved firing goofball atheist Penn @pennjill...        NaN
# 7371  15-07-16  I hear @pennjillette show on Broadway is terri...        NaN
# 7372  15-07-16  Irrelevant clown @KarlRove sweats and shakes n...        NaN
# 7373  15-07-16  "@HoustonWelder: Donald Trump is one of the se...        NaN
# 7374  15-07-16  RT @marklevinshow: Trump: Rove is a clown and ...        NaN
#
#       twt_favourites_is_this_like_question_mark  retweets
# 0                                        127213     41112
# 1                                        141527     28654
# 2                                        183729     50039
# 3                                        214001     67010
# 4                                        178499     36688
# ...                                         ...       ...
# 7370                                        953       431
# 7371                                       1175      1086
# 7372                                       1494       930
# 7373                                       1800      1738
# 7374                                        962       689
#
# [7375 rows x 5 columns]

# %%
# json_file = "donald_data2.json", lines=True
# donald_json_df = pd.read_json(json_file)
donald_json_file = pd.read_json('donald_data2.json', lines=True)
donald_json_file.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2018-09-11 20:16:49+00:00  1039608725819088899  1039608725819088896
# 1 2018-09-11 16:48:49+00:00  1039556378766069760  1039556378766069760
# 2 2018-09-11 15:32:28+00:00  1039537164458053633  1039537164458053632
# 3 2018-09-11 12:58:10+00:00  1039498334594052096  1039498334594052096
# 4 2018-09-11 12:24:52+00:00  1039489954223542274  1039489954223542272
#
#                                            full_text  truncated  \
# 0  The safety of American people is my absolute h...      False
# 1  Small Business Optimism Soars to Highest Level...      False
# 2  #NeverForget #September11th \nhttps://t.co/l8W...      False
# 3                     17 years since September 11th!      False
# 4  Departing Washington, D.C. to attend a Flight ...      False
#
#   display_text_range                                           entities  \
# 0           [0, 185]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 106]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2            [0, 52]  {'hashtags': [{'text': 'NeverForget', 'indices...
# 3            [0, 30]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 136]  {'hashtags': [{'text': 'NeverForget', 'indices...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1039608069599240194, 'id_str...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'media': [{'id': 1039489901690056704, 'id_str...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ...  retweet_count  favorite_count  favorited retweeted possibly_sensitive  \
# 0  ...           7270           27341      False     False                0.0
# 1  ...           8520           31085      False     False                0.0
# 2  ...           9641           33968      False     False                0.0
# 3  ...          17952           73372      False     False                NaN
# 4  ...          12541           52227      False     False                0.0
#
#    lang  quoted_status_id quoted_status_id_str  quoted_status_permalink  \
# 0    en               NaN                  NaN                      NaN
# 1    en               NaN                  NaN                      NaN
# 2   und               NaN                  NaN                      NaN
# 3    en               NaN                  NaN                      NaN
# 4    en               NaN                  NaN                      NaN
#
#    quoted_status
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 30 columns]

# %%
for col in donald_json_file: 
    print(col)
# Out:
# created_at
# id
# id_str
# full_text
# truncated
# display_text_range
# entities
# extended_entities
# source
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# lang
# quoted_status_id
# quoted_status_id_str
# quoted_status_permalink
# quoted_status

# %%
clean_json_df = donald_json_file[["created_at", "full_text", "favorite_count", "retweet_count"]].copy()
clean_json_df
# Out:
#                     created_at  \
# 0    2018-09-11 20:16:49+00:00
# 1    2018-09-11 16:48:49+00:00
# 2    2018-09-11 15:32:28+00:00
# 3    2018-09-11 12:58:10+00:00
# 4    2018-09-11 12:24:52+00:00
# ...                        ...
# 2860 2017-09-06 10:53:45+00:00
# 2861 2017-09-06 10:51:52+00:00
# 2862 2017-09-06 10:47:01+00:00
# 2863 2017-09-06 00:38:27+00:00
# 2864 2017-09-05 20:45:27+00:00
#
#                                               full_text  favorite_count  \
# 0     The safety of American people is my absolute h...           27341
# 1     Small Business Optimism Soars to Highest Level...           31085
# 2     #NeverForget #September11th \nhttps://t.co/l8W...           33968
# 3                        17 years since September 11th!           73372
# 4     Departing Washington, D.C. to attend a Flight ...           52227
# ...                                                 ...             ...
# 2860  Hurricane looks like largest ever recorded in ...           56660
# 2861  Watching Hurricane closely. My team, which has...          104511
# 2862  Will be going to North Dakota today to discuss...           85389
# 2863  Congress now has 6 months to legalize DACA (so...           87620
# 2864  I look forward to working w/ D's + R's in Cong...           98351
#
#       retweet_count
# 0              7270
# 1              8520
# 2              9641
# 3             17952
# 4             12541
# ...             ...
# 2860          12226
# 2861          20181
# 2862          16359
# 2863          22484
# 2864          22529
#
# [2865 rows x 4 columns]

# %%
rds_connection_string = "postgres:Catpuss10!@localhost:5432/trump"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['json_tweets', 'csv_tweets']

# %%
clean_csv_df.to_sql(name='csv_tweets', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from csv_tweets', con=engine).head()
# Out:
#                                           tweet_text   hashtags  \
# 0  Today we express our deepest gratitude to all ...  ThankAVet
# 1  Busy day planned in New York. Will soon be mak...       None
# 2  Love the fact that the small groups of protest...       None
# 3  Just had a very open and successful presidenti...       None
# 4  A fantastic day in D.C. Met with President Oba...       None
#
#    twt_favourites_is_this_like_question_mark  retweets      date
# 0                                     127213     41112  16-11-11
# 1                                     141527     28654  16-11-11
# 2                                     183729     50039  16-11-11
# 3                                     214001     67010  16-11-11
# 4                                     178499     36688  16-11-11

# %%
clean_json_df.to_sql(name='json_tweets', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from json_tweets', con=engine).head()
